# %% [markdown]
# <a href="https://colab.research.google.com/github/dgutiluns/water-anomaly-ca/blob/main/modeling_sample_and_streamcat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestRegressor, IsolationForest
from google.colab import drive

# %%
drive.mount('/content/drive')


path = '/content/drive/MyDrive/Year 3 Berk/Data Discovery Group Folder/sample_with_streamcat.csv'
df = pd.read_csv(path)
df.head()
# Out:
# Mounted at /content/drive
# /tmp/ipython-input-2333323550.py:5: DtypeWarning: Columns (28,29,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
#    _id         Program             ParentProject  \
# 0    1  Proposition 84  Prop84-City of San Diego
# 1    2  Proposition 84  Prop84-City of San Diego
# 2    3  Proposition 84  Prop84-City of San Diego
# 3    4  Proposition 84  Prop84-City of San Diego
# 4    5  Proposition 84  Prop84-City of San Diego
#
#                                              Project StationName StationCode  \
# 0  City of San Diego Hypolimnetic Oxygenation System         HGA         HGA
# 1  City of San Diego Hypolimnetic Oxygenation System         HGA         HGA
# 2  City of San Diego Hypolimnetic Oxygenation System         HGA         HGA
# 3  City of San Diego Hypolimnetic Oxygenation System         HGA         HGA
# 4  City of San Diego Hypolimnetic Oxygenation System         HGA         HGA
#
#             SampleDate CollectionTime  LocationCode  CollectionDepth  ...  \
# 0  2017-04-18T00:00:00          00:00  Not Recorded              0.0  ...
# 1  2017-04-18T00:00:00          00:00  Not Recorded              3.0  ...
# 2  2017-04-18T00:00:00          00:00  Not Recorded              6.0  ...
# 3  2017-04-18T00:00:00          00:00  Not Recorded              9.0  ...
# 4  2017-04-18T00:00:00          00:00  Not Recorded             12.0  ...
#
#   prism_norm_8110.precip8110ws prism_norm_8110.tmean8110ws  \
# 0                   477.242082                   16.407631
# 1                   477.242082                   16.407631
# 2                   477.242082                   16.407631
# 3                   477.242082                   16.407631
# 4                   477.242082                   16.407631
#
#    prism_norm_8110.tmax8110ws  prism_norm_8110.tmin8110ws wetness.wetindexws  \
# 0                   24.216835                     8.59334           687.8284
# 1                   24.216835                     8.59334           687.8284
# 2                   24.216835                     8.59334           687.8284
# 3                   24.216835                     8.59334           687.8284
# 4                   24.216835                     8.59334           687.8284
#
#   wetness.wetindexcat runoff.runoffws runoff.runoffcat  \
# 0            714.2622         38.9634          39.3049
# 1            714.2622         38.9634          39.3049
# 2            714.2622         38.9634          39.3049
# 3            714.2622         38.9634          39.3049
# 4            714.2622         38.9634          39.3049
#
#   landfire_veg.pctnonagintrodmanagvegws landfire_veg.pctnonagintrodmanagvegcat
# 0                                 16.61                                   1.61
# 1                                 16.61                                   1.61
# 2                                 16.61                                   1.61
# 3                                 16.61                                   1.61
# 4                                 16.61                                   1.61
#
# [5 rows x 183 columns]

# %%
# Work on a deep copy so the original df stays intact
df_proc = df.copy(deep=True)

# 1) Coerce numeric on the copy
num_cols = ["Result","RL","MDL","DilutionFactor","Latitude","Longitude"]
for c in num_cols:
    if c in df_proc.columns:
        df_proc[c] = pd.to_numeric(df_proc[c], errors="coerce")

# 2) Fill censored values (Result -> RL -> MDL)
mask_empty  = df_proc["Result"].isna()
mask_rl_bad = df_proc["RL"].isna() | (df_proc["RL"] < 0)

df_proc["Result_filled"] = df_proc["Result"]
df_proc.loc[mask_empty & ~mask_rl_bad, "Result_filled"] = df_proc.loc[mask_empty & ~mask_rl_bad, "RL"]
df_proc.loc[mask_empty &  mask_rl_bad, "Result_filled"] = df_proc.loc[mask_empty &  mask_rl_bad, "MDL"]

# Audit flag
df_proc["SubbedFrom"] = np.where(mask_empty & ~mask_rl_bad, "RL",
                         np.where(mask_empty & mask_rl_bad, "MDL", "Result"))

# 3) Normalize units to µg/L
def to_ugL(val, unit):
    if pd.isna(val): return np.nan
    u = (str(unit) if unit is not None else "").strip().lower()
    if u in ["µg/l","ug/l","micrograms per liter","microgram per liter"]:
        return float(val)
    if u in ["mg/l","milligrams per liter","milligram per liter"]:
        return float(val) * 1000.0
    if u in ["ng/l","nanograms per liter","nanogram per liter"]:
        return float(val) * 0.001
    # Unknown → pass through
    return float(val)

df_proc["Result_ugL"] = [to_ugL(v, u) for v, u in zip(df_proc["Result_filled"], df_proc.get("Unit", np.nan))]
# Out:
#         _id                   Program  \
# 0         1            Proposition 84
# 1         2            Proposition 84
# 2         3            Proposition 84
# 3         4            Proposition 84
# 4         5            Proposition 84
# ...     ...                       ...
# 8610  49978  Total Maximum Daily Load
# 8611  49984  Total Maximum Daily Load
# 8612  49987  Total Maximum Daily Load
# 8613  49993  Total Maximum Daily Load
# 8614  49996  Total Maximum Daily Load
#
#                                     ParentProject  \
# 0                        Prop84-City of San Diego
# 1                        Prop84-City of San Diego
# 2                        Prop84-City of San Diego
# 3                        Prop84-City of San Diego
# 4                        Prop84-City of San Diego
# ...                                           ...
# 8610  Nutrient TMDL for Santa Margarita Watershed
# 8611  Nutrient TMDL for Santa Margarita Watershed
# 8612  Nutrient TMDL for Santa Margarita Watershed
# 8613  Nutrient TMDL for Santa Margarita Watershed
# 8614  Nutrient TMDL for Santa Margarita Watershed
#
#                                                 Project  \
# 0     City of San Diego Hypolimnetic Oxygenation System
# 1     City of San Diego Hypolimnetic Oxygenation System
# 2     City of San Diego Hypolimnetic Oxygenation System
# 3     City of San Diego Hypolimnetic Oxygenation System
# 4     City of San Diego Hypolimnetic Oxygenation System
# ...                                                 ...
# 8610        Nutrient TMDL for Santa Margarita Watershed
# 8611        Nutrient TMDL for Santa Margarita Watershed
# 8612        Nutrient TMDL for Santa Margarita Watershed
# 8613        Nutrient TMDL for Santa Margarita Watershed
# 8614        Nutrient TMDL for Santa Margarita Watershed
#
#                                             StationName StationCode  \
# 0                                                   HGA         HGA
# 1                                                   HGA         HGA
# 2                                                   HGA         HGA
# 3                                                   HGA         HGA
# 4                                                   HGA         HGA
# ...                                                 ...         ...
# 8610  Pipe discharging to Brow Ditch on Huffstatler St.       HST02
# 8611                    Rainbow Creek @ Old Highway 395       RBC04
# 8612                    Rainbow Creek @ Old Highway 395       RBC04
# 8613            Rainbow Glen Tributary to Rainbow Creek       RGT01
# 8614            Rainbow Glen Tributary to Rainbow Creek       RGT01
#
#                SampleDate CollectionTime  LocationCode  CollectionDepth  ...  \
# 0     2017-04-18T00:00:00          00:00  Not Recorded              0.0  ...
# 1     2017-04-18T00:00:00          00:00  Not Recorded              3.0  ...
# 2     2017-04-18T00:00:00          00:00  Not Recorded              6.0  ...
# 3     2017-04-18T00:00:00          00:00  Not Recorded              9.0  ...
# 4     2017-04-18T00:00:00          00:00  Not Recorded             12.0  ...
# ...                   ...            ...           ...              ...  ...
# 8610  2022-01-10T00:00:00          10:12  Not Recorded            -88.0  ...
# 8611  2022-01-10T00:00:00          10:26  Not Recorded            -88.0  ...
# 8612  2022-01-10T00:00:00          10:26  Not Recorded            -88.0  ...
# 8613  2022-01-10T00:00:00          10:55  Not Recorded            -88.0  ...
# 8614  2022-01-10T00:00:00          10:55  Not Recorded            -88.0  ...
#
#      prism_norm_8110.tmin8110ws wetness.wetindexws  wetness.wetindexcat  \
# 0                      8.593340           687.8284             714.2622
# 1                      8.593340           687.8284             714.2622
# 2                      8.593340           687.8284             714.2622
# 3                      8.593340           687.8284             714.2622
# 4                      8.593340           687.8284             714.2622
# ...                         ...                ...                  ...
# 8610                  11.144219           678.6893             688.0435
# 8611                  11.144219           678.6893             688.0435
# 8612                  11.144219           678.6893             688.0435
# 8613                  11.585818           617.7526             617.7526
# 8614                  11.585818           617.7526             617.7526
#
#       runoff.runoffws runoff.runoffcat landfire_veg.pctnonagintrodmanagvegws  \
# 0             38.9634          39.3049                                 16.61
# 1             38.9634          39.3049                                 16.61
# 2             38.9634          39.3049                                 16.61
# 3             38.9634          39.3049                                 16.61
# 4             38.9634          39.3049                                 16.61
# ...               ...              ...                                   ...
# 8610          28.8988          28.6356                                  2.50
# 8611          28.8988          28.6356                                  2.50
# 8612          28.8988          28.6356                                  2.50
# 8613          27.0000          27.0000                                  2.69
# 8614          27.0000          27.0000                                  2.69
#
#      landfire_veg.pctnonagintrodmanagvegcat Result_filled SubbedFrom  \
# 0                                      1.61         0.050        MDL
# 1                                      1.61         0.050        MDL
# 2                                      1.61         0.492     Result
# 3                                      1.61         0.662     Result
# 4                                      1.61         0.759     Result
# ...                                     ...           ...        ...
# 8610                                   4.69        59.000     Result
# 8611                                   4.69      1790.000     Result
# 8612                                   4.69        56.000     Result
# 8613                                   2.69      1250.000     Result
# 8614                                   2.69       202.000     Result
#
#      Result_ugL
# 0          50.0
# 1          50.0
# 2         492.0
# 3         662.0
# 4         759.0
# ...         ...
# 8610       59.0
# 8611  1790000.0
# 8612       56.0
# 8613  1250000.0
# 8614      202.0
#
# [8615 rows x 186 columns]

# %%
# Overall missingness table
summary = (
    pd.DataFrame({
        "column": df_proc.columns,
        "dtype": [str(df_proc[c].dtype) for c in df_proc.columns],
        "n_missing": [df_proc[c].isna().sum() for c in df_proc.columns],
    })
    .assign(n=len(df_proc))
)
summary["missing_rate"] = summary["n_missing"] / summary["n"]

# Target substitution audit
summary_target = pd.DataFrame({
    "total_rows": [len(df_proc)],
    "result_non_null": [df_proc["Result"].notna().sum()],
    "subbed_from_RL": [int((df_proc["SubbedFrom"]=="RL").sum())],
    "subbed_from_MDL": [int((df_proc["SubbedFrom"]=="MDL").sum())],
    "units_missing_in_target": [int(df_proc.loc[df_proc["Result"].isna(), "Unit"].isna().sum())]
})
summary.sort_values("missing_rate", ascending=False, inplace=True)

print("Target substitution audit:")
display(summary_target)
print("\nTop 30 columns by missing rate:")
display(summary.head(30))
# Out:
# Target substitution audit:
#    total_rows  result_non_null  subbed_from_RL  subbed_from_MDL  \
# 0        8615             7901             410              304
#
#    units_missing_in_target
# 0                        0
# Top 30 columns by missing rate:
#                        column    dtype  n_missing     n  missing_rate
# 21                Observation  float64       8615  8615      1.000000
# 35               GroupSamples  float64       8615  8615      1.000000
# 53               StartingBank  float64       8615  8615      1.000000
# 55       UnitDistanceFromBank  float64       8615  8615      1.000000
# 54           DistanceFromBank  float64       8615  8615      1.000000
# 57            UnitStreamWidth  float64       8615  8615      1.000000
# 52           OccupationMethod  float64       8615  8615      1.000000
# 60                   HydroMod  float64       8615  8615      1.000000
# 59      UnitStationWaterDepth  float64       8615  8615      1.000000
# 58          StationWaterDepth  float64       8615  8615      1.000000
# 65           DownStreamLength  float64       8615  8615      1.000000
# 64             UpstreamLength  float64       8615  8615      1.000000
# 63               ChannelWidth  float64       8615  8615      1.000000
# 62   LocationDetailWQComments  float64       8615  8615      1.000000
# 61                HydroModLoc  float64       8615  8615      1.000000
# 66                 TotalReach  float64       8615  8615      1.000000
# 67   LocationDetailBAComments  float64       8615  8615      1.000000
# 48              ExpectedValue  float64       8603  8615      0.998607
# 30            ResultsComments   object       8527  8615      0.989785
# 31              BatchComments   object       8211  8615      0.953105
# 28             SampleComments   object       7899  8615      0.916889
# 25                     QACode   object       7444  8615      0.864074
# 29         CollectionComments   object       6455  8615      0.749275
# 44        DigestExtractMethod   object       2642  8615      0.306674
# 15                LabSampleID   object       2314  8615      0.268601
# 68                   SampleID   object       2242  8615      0.260244
# 71       DataQualityIndicator   object       2214  8615      0.256994
# 42       PrepPreservationName   object       1736  8615      0.201509
# 26          BatchVerification   object       1626  8615      0.188741
# 170            napd.sn2008cat  float64       1341  8615      0.155659

# %%
# Columns that have any missingness
cols_with_missing = summary.loc[summary["n_missing"] > 0, "column"].tolist()

def miss_rate_by_group(df_like, group_col, cols):
    out = []
    for c in cols:
        mr = df_like.groupby(group_col)[c].apply(lambda s: s.isna().mean())
        out.append(mr.rename(c))
    return pd.concat(out, axis=1)

miss_analyte = miss_rate_by_group(df_proc, "Analyte", cols_with_missing)

# Worst offenders averaged across analytes
mean_miss_by_col = miss_analyte.mean(axis=0).sort_values(ascending=False)
print("Columns with highest average missing rate across analytes:")
display(mean_miss_by_col.head(20))

# Save wide table
# miss_analyte.to_csv("missingness_by_analyte.csv")
# print("Wrote missingness_by_analyte.csv")
# Out:
# Columns with highest average missing rate across analytes:
# Observation                 1.000000
# GroupSamples                1.000000
# StartingBank                1.000000
# UnitDistanceFromBank        1.000000
# DistanceFromBank            1.000000
# UnitStreamWidth             1.000000
# OccupationMethod            1.000000
# HydroMod                    1.000000
# UnitStationWaterDepth       1.000000
# StationWaterDepth           1.000000
# DownStreamLength            1.000000
# UpstreamLength              1.000000
# ChannelWidth                1.000000
# LocationDetailWQComments    1.000000
# HydroModLoc                 1.000000
# TotalReach                  1.000000
# LocationDetailBAComments    1.000000
# ExpectedValue               0.997254
# ResultsComments             0.988640
# SampleComments              0.930072
# dtype: float64

# %%
still_missing_target = df_proc["Result_ugL"].isna().values.sum(0)
still_missing_target
# Out:
# np.int64(0)

# %%
# --- choose your target (optionally log-transform per analyte)
y = df_proc["Result_ugL"].to_numpy()
X = df_proc[feature_cols].to_numpy()

# 1) OOF predictions
kf = KFold(n_splits=5, shuffle=True, random_state=42)
oof_pred = np.zeros_like(y, dtype=float)

for tr, te in kf.split(X):
    model = RandomForestRegressor(n_estimators=500, n_jobs=-1, random_state=42)
    model.fit(X[tr], y[tr])
    oof_pred[te] = model.predict(X[te])

resid = y - oof_pred          # or np.log1p(y) - np.log1p(oof_pred)
abs_resid = np.abs(resid)

# 2) Isolation Forest on residuals
iso = IsolationForest(contamination=0.05, random_state=42)
labels = iso.fit_predict(abs_resid.reshape(-1, 1))   # -1 = outlier, 1 = inlier

df["residual"] = resid
df["if_label"] = labels
df["is_outlier"] = (labels == -1)
